# %% [markdown]
# ## In this Project i will cover the Regression Model practice using the Boston Housing Dataset.

# %% [markdown]
# ** Project
#
# * Task 1 Regression Models using scikert Learn
# * Task 2 Model evaluation

# %%
pip install warning
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement warning (from versions: none)
# ERROR: No matching distribution found for warning

# %%
pip install matplotlib inline
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from sklearn.linear_model import LinearRegression
import warnings
warnings.filterwarnings('ignore')

# set warning filters to ignore 
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Training the data pre-processing
#  * pre-processing the data
#  * Assumptions of data shape
#  * outliers or error
#  * missing values
#  * data transformation
#  * data normalization
#  * categorical data

# %%
full_data = pd.read_csv('./data_set/USA_Housing.csv')

# %%
full_data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
# Remove the address column as it is not needed for the analysis
full_data = full_data.drop('Address', axis=1)

# %%
full_data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
# Numeric Summary 
full_data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ## Getting Model Ready

# %%
# shape the train model 
full_data.shape
# Out:
# (5000, 6)

# %% [markdown]
# ## Objective 2 Machine learning

# %%
# split the data to be used in the model
X = full_data.drop('Price', axis=1)
y = full_data['Price']

# %%
# train test models
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
from sklearn import preprocessing

pre_process = preprocessing.StandardScaler().fit(X)
x_trainsform = pre_process.transform(X)

# %%
x_trainsform.shape
# Out:
# (5000, 5)

# %%
y.shape
# Out:
# (5000,)

# %%
y_test
# Out:
# 1718    1.251689e+06
# 2511    8.730483e+05
# 345     1.696978e+06
# 2521    1.063964e+06
# 54      9.487883e+05
#             ...
# 3900    1.466412e+06
# 3753    1.222412e+06
# 3582    1.404622e+06
# 2392    9.100996e+05
# 3343    1.188197e+06
# Name: Price, Length: 1000, dtype: float64

# %%
 pip install StandarScaler
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement StandarScaler (from versions: none)
# ERROR: No matching distribution found for StandarScaler

# %%
## model training 
# fit 
# import the model
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# creat the instance of model
lin_reg = LinearRegression()

# pass the training into model 
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pipe = make_pipeline(StandardScaler(), LinearRegression())
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
##  Model Testing 

# Classification prediction
y_pred = lin_reg.predict(X_test)
print(y_pred.shape)
print(y_pred)
# Out:
# (1000,)
# [1257919.729097    822112.41884197 1740669.05865495  972452.12917494
#   993422.26329315  644126.07414456 1073911.79101682  856584.00194133
#  1445318.25518365 1204342.19071174 1455792.46212863 1298556.65696433
#  1735924.33836095 1336925.77577789 1387637.43231922 1222403.77772069
#   613786.28691982  963933.54416267 1221197.33050139 1198071.57563599
#   505861.89531673 1769106.54723353 1853881.16842511 1200369.50507868
#  1065129.1285072  1812033.73067312 1768686.47091262 1439920.83814323
#  1387251.99649376 1541178.39224181  726418.80504278 1754497.60908688
#  1462185.72653198 1025600.16081145 1284926.8685155   917454.59590853
#  1187046.94956865  999330.91117487 1329536.63409595  782191.60441437
#  1393272.03053841  578216.88394851  822643.37151048 1895533.11413226
#  1672019.84892041  966926.45434583 1129674.55638146  792797.75914663
#  1161057.18412143 1472396.71417164 1457656.70412313 1162939.334229
# ...

# %%
sns.scatterplot(x=y_test, y=y_pred, color='blue', label="Actual Data points ")
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.show()

# %%
import numpy as np

results = np.column_stack((y_test, y_pred))

# Pirnting the results

print("Actual Price,----------------  Predicted Price")

for actual, predicted in results:
    
    print(f"{actual:14.2f}----------------{predicted:12.2f}")
# Out:
# Actual Price,----------------  Predicted Price
#     1251688.62----------------  1257919.73
#      873048.32----------------   822112.42
#     1696977.66----------------  1740669.06
#     1063964.29----------------   972452.13
#      948788.28----------------   993422.26
#      730043.65----------------   644126.07
#     1166925.15----------------  1073911.79
#      705444.12----------------   856584.00
#     1499988.88----------------  1445318.26
#     1288199.15----------------  1204342.19
#     1441736.76----------------  1455792.46
#     1279681.15----------------  1298556.66
#     1754969.16----------------  1735924.34
#     1511653.45----------------  1336925.78
#     1441956.20----------------  1387637.43
#     1119992.62----------------  1222403.78
#      727866.53----------------   613786.29
#     1138885.10----------------   963933.54
#     1074263.32----------------  1221197.33
#     1386473.37----------------  1198071.58
#      404643.60----------------   505861.90
# ...

# %%
y_pred
# Out:
# array([1257919.729097  ,  822112.41884197, 1740669.05865495,
#         972452.12917494,  993422.26329315,  644126.07414456,
#        1073911.79101682,  856584.00194133, 1445318.25518365,
#        1204342.19071174, 1455792.46212863, 1298556.65696433,
#        1735924.33836095, 1336925.77577789, 1387637.43231922,
#        1222403.77772069,  613786.28691982,  963933.54416267,
#        1221197.33050139, 1198071.57563599,  505861.89531673,
#        1769106.54723353, 1853881.16842511, 1200369.50507868,
#        1065129.1285072 , 1812033.73067312, 1768686.47091262,
#        1439920.83814323, 1387251.99649376, 1541178.39224181,
#         726418.80504278, 1754497.60908688, 1462185.72653198,
#        1025600.16081145, 1284926.8685155 ,  917454.59590853,
#        1187046.94956865,  999330.91117487, 1329536.63409595,
#         782191.60441437, 1393272.03053841,  578216.88394851,
#         822643.37151048, 1895533.11413226, 1672019.84892041,
# ...

# %%
y_pred.reshape(-1)
# Out:
# array([1257919.729097  ,  822112.41884197, 1740669.05865495,
#         972452.12917494,  993422.26329315,  644126.07414456,
#        1073911.79101682,  856584.00194133, 1445318.25518365,
#        1204342.19071174, 1455792.46212863, 1298556.65696433,
#        1735924.33836095, 1336925.77577789, 1387637.43231922,
#        1222403.77772069,  613786.28691982,  963933.54416267,
#        1221197.33050139, 1198071.57563599,  505861.89531673,
#        1769106.54723353, 1853881.16842511, 1200369.50507868,
#        1065129.1285072 , 1812033.73067312, 1768686.47091262,
#        1439920.83814323, 1387251.99649376, 1541178.39224181,
#         726418.80504278, 1754497.60908688, 1462185.72653198,
#        1025600.16081145, 1284926.8685155 ,  917454.59590853,
#        1187046.94956865,  999330.91117487, 1329536.63409595,
#         782191.60441437, 1393272.03053841,  578216.88394851,
#         822643.37151048, 1895533.11413226, 1672019.84892041,
# ...

# %%
# residula plot 

residual = actual - y_pred.reshape(-1)
print(residual)
# Out:
# [-6.97228472e+04  3.66084463e+05 -5.52472177e+05  2.15744753e+05
#   1.94774619e+05  5.44070808e+05  1.14285091e+05  3.31612880e+05
#  -2.57121373e+05 -1.61453088e+04 -2.67595580e+05 -1.10359775e+05
#  -5.47727456e+05 -1.48728894e+05 -1.99440550e+05 -3.42068958e+04
#   5.74410595e+05  2.24263338e+05 -3.30004486e+04 -9.87469372e+03
#   6.82334987e+05 -5.80909665e+05 -6.65684287e+05 -1.21726232e+04
#   1.23067753e+05 -6.23836849e+05 -5.80489589e+05 -2.51723956e+05
#  -1.99055115e+05 -3.52981510e+05  4.61778077e+05 -5.66300727e+05
#  -2.73988845e+05  1.62596721e+05 -9.67299866e+04  2.70742286e+05
#   1.14993234e+03  1.88865971e+05 -1.41339752e+05  4.06005277e+05
#  -2.05075149e+05  6.09979998e+05  3.65553510e+05 -7.07336232e+05
#  -4.83822967e+05  2.21270428e+05  5.85223255e+04  3.95399123e+05
#   2.71396978e+04 -2.84199832e+05 -2.69459822e+05  2.52575477e+04
#   8.87432008e+04 -1.69910564e+05  3.47093178e+05  2.01874576e+05
# ...

# %%
# distribution plot for residual (difference between actual and predicted)
sns.displot(residual, bins=50, kde=True, color='blue')

# %%
# linear regression 

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score 
from sklearn.tree import DecisionTreeRegressor 
# import root mean square error

print('Linear Regression Model')
# results 
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)


# print the evaltion metrics
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Linear Regression Model
# Mean Squared Error: 10100187858.864885
# Root Mean Squared Error: 100499.69083964829

# %%
##  Decision Tree 
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
rfg_regressor = DecisionTreeRegressor()
rfg_regressor.fit(X_train, y_train)


# predicting the sales prices using t test set 

y_pred = rfg_regressor.predict(X_test)


Dtr = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(Dtr)
print('Decision Tree Regressor',Dtr)
print('Root mean square error', rmse)
# Out:
# Decision Tree Regressor 33033418498.69685
# Root mean square error 181750.97936103906

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

rf_regressor = RandomForestRegressor()
rf_regressor.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
# predicting the model of regresser random forest 

y_pred_rf = rf_regressor.predict(X_test)

Rfr = mean_squared_error(y_test, y_pred_rf)
rmse = np.sqrt(Rfr)

# Random Forest Regressor
print('Random Forest Regressor',Rfr)
print('Root mean square error', rmse)
# Out:
# Random Forest Regressor 14861722756.184338
# Root mean square error 121908.6656320392

# %%
# Gradient Boosting Regressor

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingClassifier

rfg_regressor = GradientBoostingRegressor()

# Predicting the model of regressor gradient boosting 
GBr = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(GBr)

print("Gradient Boosting Regressor", GBr)
print("Root mean square error", rmse)
# Out:
# Gradient Boosting Regressor 14861722756.184338
# Root mean square error 121908.6656320392

# %%
# Sample model scores  = (Replace these with actual models scores)

model_scores = {
    
    "LinearRegression" : 10100187858.864885,
    "DecisionTreeRegressor" : 33033418498.69685,
    "RandomForestRegressor" :  14861722756.184338,
    "GradientBoostingRegressor" : 14861722756.184338
    
    
}

# sort the model scores in ascending order
sorted_model_scores = sorted(model_scores.items(), key=lambda item: item[1])

# displayu the ranking of models 

print("Model Ranking (lower are better scores")

for rank, (model_name, score) in enumerate(sorted_model_scores, 1):
    
    print(f"{rank}. {model_name} : {score}")
# Out:
# Model Ranking (lower are better scores
# 1. LinearRegression : 10100187858.864885
# 2. RandomForestRegressor : 14861722756.184338
# 3. GradientBoostingRegressor : 14861722756.184338
# 4. DecisionTreeRegressor : 33033418498.69685
